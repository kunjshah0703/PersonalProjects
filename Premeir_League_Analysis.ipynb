# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\Kunj Shah\\OneDrive\\Desktop'

# %%
import os

# %%
os.chdir(r'C:\Users\Kunj Shah\Downloads')

# %%
pwd
# Out:
# 'C:\\Users\\Kunj Shah\\Downloads'

# %%
df = pd.read_csv(r'C:\Users\Kunj Shah\Downloads\EPL_20_21.csv')

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df.shape
# Out:
# (532, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   532 non-null    object
#  1   Club                   532 non-null    object
#  2   Nationality            532 non-null    object
#  3   Position               532 non-null    object
#  4   Age                    532 non-null    int64
#  5   Matches                532 non-null    int64
#  6   Starts                 532 non-null    int64
#  7   Mins                   532 non-null    int64
#  8   Goals                  532 non-null    int64
#  9   Assists                532 non-null    int64
#  10  Passes_Attempted       532 non-null    int64
#  11  Perc_Passes_Completed  532 non-null    float64
#  12  Penalty_Goals          532 non-null    int64
#  13  Penalty_Attempted      532 non-null    int64
# ...

# %%
df_copy = df

# %%
df_copy.isnull().sum()
# Out:
# Name                     0
# Club                     0
# Nationality              0
# Position                 0
# Age                      0
# Matches                  0
# Starts                   0
# Mins                     0
# Goals                    0
# Assists                  0
# Passes_Attempted         0
# Perc_Passes_Completed    0
# Penalty_Goals            0
# Penalty_Attempted        0
# xG                       0
# xA                       0
# Yellow_Cards             0
# Red_Cards                0
# dtype: int64

# %%
df.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df_copy.groupby('Club')['Mins'].mean()
# Out:
# Club
# Arsenal                    1291.482759
# Aston Villa                1563.833333
# Brighton                   1391.703704
# Burnley                    1504.800000
# Chelsea                    1389.259259
# Crystal Palace             1566.416667
# Everton                    1296.551724
# Fulham                     1340.750000
# Leeds United               1633.652174
# Leicester City             1393.333333
# Liverpool FC               1343.571429
# Manchester City            1562.166667
# Manchester United          1295.068966
# Newcastle United           1389.629630
# Sheffield United           1387.259259
# Southampton                1291.206897
# Tottenham Hotspur          1566.833333
# West Bromwich Albion       1246.700000
# West Ham United            1564.750000
# Wolverhampton Wanderers    1393.296296
# Name: Mins, dtype: float64

# %%
df_copy.groupby('Club')['Mins'].sum()
# Out:
# Club
# Arsenal                    37453
# Aston Villa                37532
# Brighton                   37576
# Burnley                    37620
# Chelsea                    37510
# Crystal Palace             37594
# Everton                    37600
# Fulham                     37541
# Leeds United               37574
# Leicester City             37620
# Liverpool FC               37620
# Manchester City            37492
# Manchester United          37557
# Newcastle United           37520
# Sheffield United           37456
# Southampton                37445
# Tottenham Hotspur          37604
# West Bromwich Albion       37401
# West Ham United            37554
# Wolverhampton Wanderers    37619
# Name: Mins, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
import matplotlib_inline

# %%
df_copy.columns
# Out:
# Index(['Name', 'Club', 'Nationality', 'Position', 'Age', 'Matches', 'Starts',
#        'Mins', 'Goals', 'Assists', 'Passes_Attempted', 'Perc_Passes_Completed',
#        'Penalty_Goals', 'Penalty_Attempted', 'xG', 'xA', 'Yellow_Cards',
#        'Red_Cards'],
#       dtype='object')

# %%
df_copy['Penalty_Attempted']
# Out:
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 527    0
# 528    0
# 529    0
# 530    0
# 531    0
# Name: Penalty_Attempted, Length: 532, dtype: int64

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards
# ...

# %%
df_copy['Penalties_Missed'] = (df_copy['Penalty_Attempted'] - (df_copy['Penalty_Goals']))

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df_copy['Penalties_Missed'].value_counts()
# Out:
# 0    510
# 1     21
# 2      1
# Name: Penalties_Missed, dtype: int64

# %%
df_copy['Penalties_Missed'].value_counts().plot(kind='pie')
plt.legend(labels = ['Penalty Scored', 'One Missed', 'Missed more than one'], shadow = True, loc = 'upper left')

# %%
df_copy.groupby('Club')['Red_Cards'].sum()
# Out:
# Club
# Arsenal                    5
# Aston Villa                4
# Brighton                   6
# Burnley                    0
# Chelsea                    3
# Crystal Palace             2
# Everton                    2
# Fulham                     3
# Leeds United               1
# Leicester City             0
# Liverpool FC               0
# Manchester City            2
# Manchester United          1
# Newcastle United           3
# Sheffield United           3
# Southampton                3
# Tottenham Hotspur          2
# West Bromwich Albion       4
# West Ham United            3
# Wolverhampton Wanderers    1
# Name: Red_Cards, dtype: int64

# %%
df_copy.groupby('Club')['Red_Cards'].sum().plot(kind = 'bar')
plt.show()


"""plt.bar(x= 'Club', y = 'Red_Cards', height=10)
plt.show()"""
# Out:
# "plt.bar(x= 'Club', y = 'Red_Cards', height=10)\nplt.show()"

# %%
df_copy.groupby('Club')['Yellow_Cards'].sum().plot(kind = 'bar')
plt.show()

# %%
plt.bar(x = df_copy['Club'], height= df_copy['Yellow_Cards'])
plt.xticks(rotation = 90)
plt.show()

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df_copy['MinsPerMatch'] = (df_copy['Mins'] / df_copy['Matches']).astype(int)

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    MF,FW   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df_copy.groupby('Name')['MinsPerMatch'].sum()
# Out:
# Name
# Aaron Connolly        46
# Aaron Cresswell       88
# Aaron Ramsdale        90
# Aaron Wan-Bissaka     90
# Abdoulaye Doucouré    84
#                       ..
# Zack Steffen          90
# Çağlar Söyüncü        79
# Érik Lamela           31
# İlkay Gündoğan        72
# Łukasz Fabiański      90
# Name: MinsPerMatch, Length: 524, dtype: int32

# %%
df_copy['Position'].value_counts()
# Out:
# DF       178
# MF       108
# FW        81
# FW,MF     47
# GK        42
# MF,FW     36
# DF,MF     15
# MF,DF     13
# FW,DF      6
# DF,FW      6
# Name: Position, dtype: int64

# %%
df_copy.groupby(['Name','Position'])['Position'].sum()
# Out:
# Name                Position
# Aaron Connolly      FW             FW
# Aaron Cresswell     DF             DF
# Aaron Ramsdale      GK             GK
# Aaron Wan-Bissaka   DF             DF
# Abdoulaye Doucouré  MF             MF
#                                 ...
# Zack Steffen        GK             GK
# Çağlar Söyüncü      DF             DF
# Érik Lamela         FW,MF       FW,MF
# İlkay Gündoğan      MF             MF
# Łukasz Fabiański    GK             GK
# Name: Position, Length: 528, dtype: object

# %%
df_copy[(df_copy['Position'] == 'FW,MF') | (df_copy['Position'] == 'MF,FW')]
# Out:
#                   Name                  Club Nationality Position  Age  \
# 0          Mason Mount               Chelsea         ENG    MF,FW   21
# 12   Christian Pulisic               Chelsea         USA    FW,MF   21
# 13         Kai Havertz               Chelsea         GER    MF,FW   21
# 15        Hakim Ziyech               Chelsea         MAR    FW,MF   27
# 32      Bernardo Silva       Manchester City         POR    MF,FW   25
# ..                 ...                   ...         ...      ...  ...
# 494   Robert Snodgrass  West Bromwich Albion         SCO    MF,FW   32
# 498     Kamil Grosicki  West Bromwich Albion         POL    FW,MF   32
# 499       Kyle Edwards  West Bromwich Albion         ENG    MF,FW   22
# 511   David McGoldrick      Sheffield United         IRL    FW,MF   32
# 527        Lys Mousset      Sheffield United         FRA    FW,MF   24
#
#      Matches  Starts  Mins  Goals  Assists  Passes_Attempted  \
# ...

# %%
df_copy[df_copy['Position'] == 'MF,FW']
# Out:
#                     Name                     Club Nationality Position  Age  \
# 0            Mason Mount                  Chelsea         ENG    MF,FW   21
# 13           Kai Havertz                  Chelsea         GER    MF,FW   21
# 32        Bernardo Silva          Manchester City         POR    MF,FW   25
# 60            Paul Pogba        Manchester United         FRA    MF,FW   27
# 70     Donny van de Beek        Manchester United         NED    MF,FW   23
# 99       Xherdan Shaqiri             Liverpool FC         SUI    MF,FW   28
# 103      Takumi Minamino             Liverpool FC         JPN    MF,FW   25
# 115       James Maddison           Leicester City         ENG    MF,FW   23
# 122          Ayoze Pérez           Leicester City         ESP    MF,FW   27
# 125         Dennis Praet           Leicester City         BEL    MF,FW   26
# 129         Cengiz Ünder           Leicester City         TUR    MF,FW   23
# ...

# %%
df_copy[df_copy['Position'] == 'FW,MF']
# Out:
#                         Name                     Club Nationality Position  \
# 12         Christian Pulisic                  Chelsea         USA    FW,MF
# 15              Hakim Ziyech                  Chelsea         MAR    FW,MF
# 39                Phil Foden          Manchester City         ENG    FW,MF
# 41             Ferrán Torres          Manchester City         ESP    FW,MF
# 46             Sergio Agüero          Manchester City         ARG    FW,MF
# 69                 Juan Mata        Manchester United         ESP    FW,MF
# 104  Alex Oxlade-Chamberlain             Liverpool FC         ENG    FW,MF
# 117            Harvey Barnes           Leicester City         ENG    FW,MF
# 140            Pablo Fornals          West Ham United         ESP    FW,MF
# 141             Jarrod Bowen          West Ham United         ENG    FW,MF
# 147            Saïd Benrahma          West Ham United         ALG    FW,MF
# ...

# %%
df_copy['Position'].value_counts()
# Out:
# DF       178
# MF       108
# FW        81
# FW,MF     47
# GK        42
# MF,FW     36
# DF,MF     15
# MF,DF     13
# FW,DF      6
# DF,FW      6
# Name: Position, dtype: int64

# %%
def position_group(x):
    if x == 'MF,FW':
        return 'FW,MF'
    elif x == 'MF, DF':
        return 'DF,MF'
    elif x == 'DF,FW':
        return 'FW,DF'
    else:
        x
df_copy['Position'].apply(position_group)
# Out:
# 0      FW,MF
# 1       None
# 2       None
# 3       None
# 4       None
#        ...
# 527     None
# 528     None
# 529     None
# 530    FW,DF
# 531     None
# Name: Position, Length: 532, dtype: object

# %%
df_copy['Position'] = df_copy['Position'].apply(lambda x : 'FW,MF' if x == 'MF,FW' else x)

# %%
df_copy['Position'].value_counts()
# Out:
# DF       178
# MF       108
# FW,MF     83
# FW        81
# GK        42
# DF,MF     15
# MF,DF     13
# FW,DF      6
# DF,FW      6
# Name: Position, dtype: int64

# %%
df_copy['Position'] = df_copy['Position'].apply(lambda x : 'MF,DF' if x == 'DF,MF' else x)

# %%
df_copy['Position'] = df_copy['Position'].apply(lambda x : 'FW,DF' if x == 'DF,FW' else x)

# %%
df_copy['Position'].value_counts()
# Out:
# DF       178
# MF       108
# FW,MF     83
# FW        81
# GK        42
# MF,DF     28
# FW,DF     12
# Name: Position, dtype: int64

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df_copy.groupby(['Nationality','Name'])['Goals'].sum()
# Out:
# Nationality  Name
# ALG          Islam Slimani          0
#              Riyad Mahrez           9
#              Saïd Benrahma          1
# ARG          Alexis Mac Allister    1
#              Emiliano Martínez      0
#                                    ..
# WAL          Neil Taylor            0
#              Niall Huggins          0
#              Paul Dummett           1
#              Tyler Roberts          1
# ZIM          Marvelous Nakamba      0
# Name: Goals, Length: 524, dtype: int64

# %%
df_copy['Club'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  Passes_Attempted  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5              1881                   82.3              1
# 1      0        0              1007                   84.6              0
# 2      6        8               826                   77.2              0
# 3      3        5              1806                   78.6              0
# 4      1        2              1987                   85.0              0
#
# ...

# %%
df_copy['GoalsPerMatch'] = (df_copy['Goals']) / df_copy['Matches'].astype(float)

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  ...  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5  ...                   82.3              1
# 1      0        0  ...                   84.6              0
# 2      6        8  ...                   77.2              0
# 3      3        5  ...                   78.6              0
# 4      1        2  ...                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  Penalties_Missed  \
# ...

# %%
df_copy[(df_copy['Position'] == 'DF') & (df_copy['Goals'] >= 1)]
# Out:
#                   Name                  Club Nationality Position  Age  \
# 3         Ben Chilwell               Chelsea         ENG       DF   23
# 4          Reece James               Chelsea         ENG       DF   20
# 5    César Azpilicueta               Chelsea         ESP       DF   30
# 8         Thiago Silva               Chelsea         BRA       DF   35
# 9           Kurt Zouma               Chelsea         FRA       DF   25
# ..                 ...                   ...         ...      ...  ...
# 476    Darnell Furlong  West Bromwich Albion         ENG       DF   24
# 477         Semi Ajayi  West Bromwich Albion         NGA       DF   26
# 479       Kyle Bartley  West Bromwich Albion         ENG       DF   29
# 520       Jayden Bogle      Sheffield United         ENG       DF   20
# 521         Kean Bryan      Sheffield United         ENG       DF   23
#
#      Matches  Starts  Mins  Goals  Assists  ...  Perc_Passes_Completed  \
# ...

# %%
x_club = df_copy.groupby('Club')['Yellow_Cards'].sum().index

# %%
y_cards = df_copy.groupby('Club')['Yellow_Cards'].sum().values

# %%
plt.figure(figsize=(12,8))
plt.bar(x = x_club, height= y_cards, width=0.9, color = '#199C25')
plt.xticks(rotation = 90)
plt.xlabel('Clubs')
plt.ylabel('Number of Yellow Cards')
plt.title("Yellow cards received by Clubs", color = '#9C3B19', loc='center', fontweight = 'bold')

for i in range(len(x_club)):
    plt.text(i, y_cards[i], y_cards[i], ha = 'center', va = 'bottom', fontsize = '12')

plt.show()

# %%
df_copy.groupby('Name').Yellow_Cards.sum().head(20)
# Out:
# Name
# Aaron Connolly             0
# Aaron Cresswell            3
# Aaron Ramsdale             1
# Aaron Wan-Bissaka          3
# Abdoulaye Doucouré         6
# Aboubakar Kamara           1
# Adam Lallana               0
# Adam Webster               4
# Adama Traoré               4
# Ademola Lookman            5
# Adrián                     0
# Ahmed Elmohamady           2
# Ahmed Hegazi               0
# Ainsley Maitland-Niles     2
# Aleksandar Mitrović        3
# Alex Iwobi                 0
# Alex McCarthy              2
# Alex Oxlade-Chamberlain    0
# Alex Telles                0
# Alexandre Jankewitz        0
# Name: Yellow_Cards, dtype: int64

# %%
x_player = df_copy.groupby('Name')['Yellow_Cards'].sum().index
y_cards1 = df_copy.groupby('Name')['Yellow_Cards'].sum().values

# %%
plt.figure(figsize=(12,8))
plt.bar(x = x_player, height=y_cards1)
plt.xticks(rotation = 90)
plt.show()

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  ...  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5  ...                   82.3              1
# 1      0        0  ...                   84.6              0
# 2      6        8  ...                   77.2              0
# 3      3        5  ...                   78.6              0
# 4      1        2  ...                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  Penalties_Missed  \
# ...

# %%
x_nat = df_copy.groupby('Nationality')['Position'].count().index

# %%
y_pos = df_copy.groupby('Nationality')['Position'].count().values

# %%
plt.figure(figsize=(15,10))
plt.bar(x = x_nat, height=y_pos, width=0.9)
plt.xticks(rotation = 90)
for i in range(len(x_nat)):
    plt.text(i, y_pos[i], y_pos[i], ha = 'center', va = 'bottom')

plt.show()

# %%
print(x_nat)
# Out:
# Index(['ALG', 'ARG', 'AUS', 'AUT', 'BEL', 'BFA', 'BIH', 'BRA', 'CAN', 'CIV',
#        'CMR', 'COD', 'COL', 'CRO', 'CZE', 'DEN', 'EGY', 'ENG', 'ESP', 'FRA',
#        'GAB', 'GER', 'GHA', 'GRE', 'GUI', 'IRL', 'IRN', 'ISL', 'ITA', 'JAM',
#        'JPN', 'KOR', 'MAR', 'MEX', 'MKD', 'MLI', 'MTN', 'NED', 'NGA', 'NIR',
#        'NOR', 'NZL', 'PAR', 'POL', 'POR', 'RSA', 'SCO', 'SEN', 'SKN', 'SRB',
#        'SUI', 'SVK', 'SWE', 'TUR', 'UKR', 'URU', 'USA', 'WAL', 'ZIM'],
#       dtype='object', name='Nationality')

# %%
x_nat1 = df_copy.groupby('Position')['Nationality'].count().index
y_pos1 = df_copy.groupby('Position')['Nationality'].count().values
plt.figure(figsize=(12,8))
plt.bar(x = x_nat1, height=y_pos1, width=0.9)
plt.xticks(rotation = 90)
for i in range(len(x_nat1)):
    plt.text(i, y_pos1[i], y_pos1[i], ha = 'center', va = 'bottom')

plt.show()

# %%
df_copy['Nationality'].value_counts()
# Out:
# ENG    192
# FRA     31
# BRA     27
# ESP     26
# IRL     21
# POR     21
# SCO     20
# NED     16
# WAL     12
# BEL     11
# GER      9
# ARG      8
# CIV      8
# NGA      7
# USA      6
# DEN      6
# SUI      6
# SEN      5
# EGY      5
# ITA      5
# POL      5
# SWE      5
# GHA      5
# COL      5
# NIR      5
# TUR      5
# AUS      4
# SRB      4
# NOR      3
# ISL      3
# ALG      3
# JAM      3
# CZE      3
# GAB      2
# SVK      2
# MLI      2
# COD      2
# PAR      2
# JPN      2
# RSA      2
# CMR      2
# CRO      2
# UKR      2
# MAR      2
# ZIM      1
# MTN      1
# NZL      1
# IRN      1
# CAN      1
# MEX      1
# BFA      1
# AUT      1
# MKD      1
# BIH      1
# URU      1
# GUI      1
# GRE      1
# KOR      1
# SKN      1
# Name: Nationality, dtype: int64

# %%
x_nat2 = df_copy.query("Nationality == ['ENG', 'FRA', 'BRA', 'ESP', 'IRL']")

# %%
x_nat2
# Out:
#                   Name              Club Nationality Position  Age  Matches  \
# 0          Mason Mount           Chelsea         ENG    FW,MF   21       36
# 3         Ben Chilwell           Chelsea         ENG       DF   23       27
# 4          Reece James           Chelsea         ENG       DF   20       32
# 5    César Azpilicueta           Chelsea         ESP       DF   30       26
# 6         N'Golo Kanté           Chelsea         FRA       MF   29       30
# ..                 ...               ...         ...      ...  ...      ...
# 527        Lys Mousset  Sheffield United         FRA    FW,MF   24       11
# 528     Jack O'Connell  Sheffield United         ENG       DF   26        2
# 529      Iliman Ndiaye  Sheffield United         FRA       MF   21        1
# 530  Antwoine Hackford  Sheffield United         ENG    FW,DF   16        1
# 531        Femi Seriki  Sheffield United         ENG       DF   17        1
#
# ...

# %%
y_pos2 = df_copy.groupby('Position')['Nationality'].count().values

# %%
x_country = x_nat2.groupby('Nationality')['Position'].count().index

# %%
y_country = x_nat2.groupby('Nationality')['Position'].count().values

# %%
plt.bar(x = x_country, height=y_country)
plt.bar(x = x_pos, height=y_nopos)
plt.show()

# %%
x_pos = x_nat2.groupby('Position')['Nationality'].count().index

# %%
y_nopos = x_nat2.groupby('Position')['Nationality'].count().values

# %%
x_coug = df_copy.groupby('Nationality')['Goals'].sum().index
y_goal = df_copy.groupby('Nationality')['Goals'].sum().values

# %%
plt.figure(figsize=(15,10))
plt.bar(x = x_coug, height=y_goal, width= 0.9)
plt.xticks(rotation = 90)
plt.xlabel('Countries')
plt.ylabel('Number of Goals')
plt.title('Goals per country')
for i in range(len(x_coug)):
    plt.text(i, y_goal[i], y_goal[i], ha = 'center', va = 'bottom', fontsize = 9)
plt.show()

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  ...  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5  ...                   82.3              1
# 1      0        0  ...                   84.6              0
# 2      6        8  ...                   77.2              0
# 3      3        5  ...                   78.6              0
# 4      1        2  ...                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  Penalties_Missed  \
# ...

# %%
Top5_Assist = df_copy.groupby(['Name','Club','Matches'])['Assists'].sum().sort_values(ascending=False).head()

# %%
Top5_Assist
# Out:
# Name             Club               Matches
# Harry Kane       Tottenham Hotspur  35         14
# Bruno Fernandes  Manchester United  37         12
# Kevin De Bruyne  Manchester City    25         12
# Son Heung-min    Tottenham Hotspur  37         10
# Jack Grealish    Aston Villa        26         10
# Name: Assists, dtype: int64

# %%
df1 = pd.DataFrame(Top5_Assist)

# %%
df1.head()
# Out:
#                                            Assists
# Name            Club              Matches
# Harry Kane      Tottenham Hotspur 35            14
# Bruno Fernandes Manchester United 37            12
# Kevin De Bruyne Manchester City   25            12
# Son Heung-min   Tottenham Hotspur 37            10
# Jack Grealish   Aston Villa       26            10

# %%
df1.columns
# Out:
# Index(['Assists'], dtype='object')

# %%
Top5_Assist.to_frame()
# Out:
#                                            Assists
# Name            Club              Matches
# Harry Kane      Tottenham Hotspur 35            14
# Bruno Fernandes Manchester United 37            12
# Kevin De Bruyne Manchester City   25            12
# Son Heung-min   Tottenham Hotspur 37            10
# Jack Grealish   Aston Villa       26            10

# %%
df2 = pd.DataFrame(Top5_Assist, columns = ['Name', 'Club', 'Matches','Assists'])

# %%
df2.head()
# Out:
#                                           Name Club Matches  Assists
# Name            Club              Matches
# Harry Kane      Tottenham Hotspur 35       NaN  NaN     NaN       14
# Bruno Fernandes Manchester United 37       NaN  NaN     NaN       12
# Kevin De Bruyne Manchester City   25       NaN  NaN     NaN       12
# Son Heung-min   Tottenham Hotspur 37       NaN  NaN     NaN       10
# Jack Grealish   Aston Villa       26       NaN  NaN     NaN       10

# %%
res = Top5_Assist.reset_index()

# %%
df3 = pd.DataFrame(res)

# %%
df3.head()
# Out:
#               Name               Club  Matches  Assists
# 0       Harry Kane  Tottenham Hotspur       35       14
# 1  Bruno Fernandes  Manchester United       37       12
# 2  Kevin De Bruyne    Manchester City       25       12
# 3    Son Heung-min  Tottenham Hotspur       37       10
# 4    Jack Grealish        Aston Villa       26       10

# %%
df3.columns
# Out:
# Index(['Name', 'Club', 'Matches', 'Assists'], dtype='object')

# %%
df3['PercentofAssist'] = ((df3['Assists'] / (df3['Matches'])) * 100).sort_values(ascending=False)

# %%
df3.head().sort_values(by = 'PercentofAssist', ascending=False)
# Out:
#               Name               Club  Matches  Assists  PercentofAssist
# 2  Kevin De Bruyne    Manchester City       25       12        48.000000
# 0       Harry Kane  Tottenham Hotspur       35       14        40.000000
# 4    Jack Grealish        Aston Villa       26       10        38.461538
# 1  Bruno Fernandes  Manchester United       37       12        32.432432
# 3    Son Heung-min  Tottenham Hotspur       37       10        27.027027

# %%
df_copy.head()
# Out:
#             Name     Club Nationality Position  Age  Matches  Starts  Mins  \
# 0    Mason Mount  Chelsea         ENG    FW,MF   21       36      32  2890
# 1  Edouard Mendy  Chelsea         SEN       GK   28       31      31  2745
# 2    Timo Werner  Chelsea         GER       FW   24       35      29  2602
# 3   Ben Chilwell  Chelsea         ENG       DF   23       27      27  2286
# 4    Reece James  Chelsea         ENG       DF   20       32      25  2373
#
#    Goals  Assists  ...  Perc_Passes_Completed  Penalty_Goals  \
# 0      6        5  ...                   82.3              1
# 1      0        0  ...                   84.6              0
# 2      6        8  ...                   77.2              0
# 3      3        5  ...                   78.6              0
# 4      1        2  ...                   85.0              0
#
#    Penalty_Attempted    xG    xA  Yellow_Cards  Red_Cards  Penalties_Missed  \
# ...
